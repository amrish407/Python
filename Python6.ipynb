# %% [markdown]
# <a href="https://colab.research.google.com/github/amrish407/Python/blob/Python_Course/Python6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Sets** **and** **Dictionaries**

# %%
a = {1,4,0,2,3, -3, 67, 99, 'hello', 'world'}

# %%
type(a)
# Out:
# set

# %%
a
# Out:
# {-3, 0, 1, 2, 3, 4, 67, 99, 'hello', 'world'}

# %%
# List - insert - approx O(n) (for random insert where order not matters)

# Insertion, deletion, searching in a set - O(1) times

# %%
if 4 in a:
  print("4 is present in set")
# Out:
# 4 is present in set
